# %% [markdown]
# Importing

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras import layers, regularizers
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

MAIN_DIR = "D:\\College_Semesters\\6th Semester\\C. Deep Learning for Signal & Image Processing\\Project_New\\Dataset"
SEED = 40
os.listdir(MAIN_DIR)
# Out:
# ['ai',
#  'cha',
#  'ee',
#  'ka',
#  'la',
#  'ma',
#  'moo',
#  'nna',
#  'nnna',
#  'nu',
#  'nuu',
#  'oo',
#  'pa',
#  'ra',
#  't',
#  'tha',
#  'va',
#  'vee',
#  'vu',
#  'y',
#  'ya']

# %%
def load_images(folder):
    imgs = []
    target = 0
    labels = []
    for i in os.listdir(folder):
        subdir = os.path.join(folder, i)
        for j in os.listdir(subdir):
            img_dir = os.path.join(subdir,j)
            try:
                img = cv2.imread(img_dir)
                if img.shape[-1] == 1:
                    # convert grayscale image to RGB
                    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
                img = cv2.resize(img,(224,224))
                imgs.append(img)
                labels.append(target)
            except:
                continue
        target += 1
    
    imgs = np.array(imgs)
    labels = np.array(labels)

    return imgs, labels

# %%
data, labels = load_images(MAIN_DIR)

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

encoder = LabelEncoder()
encoder.fit(labels)
y = encoder.transform(labels)

y_one_hot = to_categorical(y, num_classes=21) # One-hot encode the target variable

norm_data = data / 255. 
norm_data.shape, norm_data[0]
# Out:
# ((2698, 224, 224, 3),
#  array([[[0.19607843, 0.36862745, 0.52941176],
#          [0.19607843, 0.36862745, 0.52941176],
#          [0.19607843, 0.36862745, 0.52941176],
#          ...,
#          [0.19215686, 0.40392157, 0.50196078],
#          [0.19215686, 0.40392157, 0.50196078],
#          [0.19215686, 0.40392157, 0.50196078]],
#
#         [[0.19607843, 0.36862745, 0.52941176],
#          [0.19607843, 0.36862745, 0.52941176],
#          [0.19607843, 0.36862745, 0.52941176],
#          ...,
#          [0.19215686, 0.40392157, 0.50196078],
#          [0.19215686, 0.40392157, 0.50196078],
#          [0.19215686, 0.40392157, 0.50196078]],
#
#         [[0.19607843, 0.36862745, 0.52941176],
#          [0.19607843, 0.36862745, 0.52941176],
#          [0.19607843, 0.36862745, 0.52941176],
#          ...,
#          [0.19215686, 0.4       , 0.50588235],
#          [0.19215686, 0.40392157, 0.50196078],
#          [0.19215686, 0.40392157, 0.50196078]],
#
#         ...,
#
#         [[0.16470588, 0.36862745, 0.48627451],
#          [0.16470588, 0.36078431, 0.47843137],
#          [0.16470588, 0.34901961, 0.47058824],
#          ...,
#          [0.20392157, 0.39607843, 0.54509804],
#          [0.20392157, 0.39607843, 0.54509804],
#          [0.20392157, 0.39607843, 0.54509804]],
#
#         [[0.17254902, 0.37647059, 0.49411765],
#          [0.16862745, 0.36470588, 0.48235294],
#          [0.16470588, 0.34901961, 0.47058824],
#          ...,
#          [0.20392157, 0.39607843, 0.54509804],
#          [0.20392157, 0.39607843, 0.54509804],
#          [0.20392157, 0.39607843, 0.54509804]],
#
#         [[0.17647059, 0.38039216, 0.49803922],
#          [0.17254902, 0.36862745, 0.48627451],
#          [0.16862745, 0.35294118, 0.4745098 ],
#          ...,
#          [0.20392157, 0.39607843, 0.54509804],
#          [0.20392157, 0.39607843, 0.54509804],
#          [0.20392157, 0.39607843, 0.54509804]]]))

# %%
# Split the data into training and test sets
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.2, random_state=42)

# Print the shapes of the split datasets
print("Train Data Shape:", train_data.shape)
print("Train Labels Shape:", train_labels.shape)
print("Test Data Shape:", test_data.shape)
print("Test Labels Shape:", test_labels.shape)
# Out:
# Train Data Shape: (2158, 224, 224, 3)
# Train Labels Shape: (2158,)
# Test Data Shape: (540, 224, 224, 3)
# Test Labels Shape: (540,)

# %%
from tensorflow.keras.utils import to_categorical

# Convert target labels to one-hot encoded format
train_labels = to_categorical(train_labels, num_classes=21)
test_labels = to_categorical(test_labels, num_classes=21)

# train_data = train_data.reshape[1:]
# test_data = test_data.reshape[1:]

# %%
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, Dense, BatchNormalization, Activation, Conv2D, Concatenate, GlobalAveragePooling2D
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# from tensorflow.keras.optimizers import Adam
# from lime import lime_image
# from skimage.segmentation import slic

# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, Dense, Conv2D, BatchNormalization, Activation, Concatenate
# from tensorflow.keras.layers import AveragePooling2D, GlobalAveragePooling2D

# def dense_block(x, num_layers, growth_rate):
#     for _ in range(num_layers):
#         x1 = BatchNormalization()(x)
#         x1 = Activation('relu')(x1)
#         x1 = Conv2D(growth_rate, kernel_size=(3, 3), padding='same')(x1)
#         x = Concatenate()([x, x1])
#     return x

# def transition_block(x, compression_factor):
#     num_filters = int(x.shape[-1])
#     num_filters = int(num_filters * compression_factor)
    
#     x = BatchNormalization()(x)
#     x = Activation('relu')(x)
#     x = Conv2D(num_filters, kernel_size=(1, 1))(x)
#     x = AveragePooling2D(pool_size=(2, 2), strides=2)(x)
#     return x

# def DenseNet(input_shape, num_classes, num_blocks, num_layers, growth_rate, compression_factor):
#     inputs = Input(shape=input_shape)
#     x = Conv2D(64, kernel_size=(7, 7), strides=(2, 2), padding='same')(inputs)
#     x = BatchNormalization()(x)
#     x = Activation('relu')(x)
#     x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)
    
#     for i in range(num_blocks - 1):
#         x = dense_block(x, num_layers, growth_rate)
#         x = transition_block(x, compression_factor)
    
#     x = dense_block(x, num_layers, growth_rate)
#     x = BatchNormalization()(x)
#     x = Activation('relu')(x)
#     x = GlobalAveragePooling2D()(x)
    
#     outputs = Dense(num_classes, activation='softmax')(x)
    
#     model = Model(inputs=inputs, outputs=outputs)
#     return model

# # Set the hyperparameters
# input_shape = norm_data.shape[1:]
# num_classes = 21
# num_blocks = 4  # Number of dense blocks
# num_layers = 4  # Number of layers in each dense block
# growth_rate = 32  # Number of filters in each layer within a dense block
# compression_factor = 0.5  # Compression factor for transition blocks

# # Create the DenseNet model
# model = DenseNet(input_shape, num_classes, num_blocks, num_layers, growth_rate, compression_factor)

# # Compile the model
# model.compile(optimizer='adam',
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])

# # Fit the model
# history = model.fit(train_data, train_labels, epochs=5, batch_size=32, validation_data=(test_data, test_labels))

# # # LIME
# # explainer = lime_image.LimeImageExplainer()

# # def preprocess_image(image):
# #     return image * 255  # Convert from normalized to original scale

# # image_to_explain = norm_data[0]  # Choose the first image from the dataset

# # explanation = explainer.explain_instance(image_to_explain, model.predict, top_labels=1, num_samples=1000, segmentation_fn=slic, preprocess_func=preprocess_image)

# # lime_image, mask = explanation.get_image_and_mask(0, positive_only=False, hide_rest=False)
 
# # ----------------

# # # LIME
# # explainer = lime_image.LimeImageExplainer()

# # image_to_explain = norm_data[0]  # Choose the first image from the dataset

# # explanation = explainer.explain_instance(image_to_explain, model.predict, top_labels=1, num_samples=1000, segmentation_fn=slic)

# # lime_image, mask = explanation.get_image_and_mask(0, positive_only=False, hide_rest=False)

# # Create the LimeImageExplainer
# explainer = lime_image.LimeImageExplainer()

# # Define the prediction function
# def predict_fn(images):
#     predictions = model.predict(images)
#     return predictions

# # Choose an image to explain
# image_to_explain = test_data[0]  # Adjust according to your image data

# # Generate the explanation
# explanation = explainer.explain_instance(image_to_explain, predict_fn, num_samples=21, segmentation_fn=slic)

# # Get the explanation image and mask
# lime_image, mask = explanation.get_image_and_mask(0, positive_only=False, hide_rest=False)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, BatchNormalization, Activation, Conv2D, Concatenate, GlobalAveragePooling2D
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Conv2D, BatchNormalization, Activation, Concatenate
from tensorflow.keras.layers import AveragePooling2D, GlobalAveragePooling2D

def dense_block(x, num_layers, growth_rate):
    for _ in range(num_layers):
        x1 = BatchNormalization()(x)
        x1 = Activation('relu')(x1)
        x1 = Conv2D(growth_rate, kernel_size=(3, 3), padding='same')(x1)
        x = Concatenate()([x, x1])
    return x

def transition_block(x, compression_factor):
    num_filters = int(x.shape[-1])
    num_filters = int(num_filters * compression_factor)
    
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters, kernel_size=(1, 1))(x)
    x = AveragePooling2D(pool_size=(2, 2), strides=2)(x)
    return x

def DenseNet(input_shape, num_classes, num_blocks, num_layers, growth_rate, compression_factor):
    inputs = Input(shape=input_shape)
    x = Conv2D(64, kernel_size=(7, 7), strides=(2, 2), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)
    
    for i in range(num_blocks - 1):
        x = dense_block(x, num_layers, growth_rate)
        x = transition_block(x, compression_factor)
    
    x = dense_block(x, num_layers, growth_rate)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = GlobalAveragePooling2D()(x)
    
    outputs = Dense(num_classes, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Set the hyperparameters
input_shape = norm_data.shape[1:]
num_classes = 21
num_blocks = 4  # Number of dense blocks
num_layers = 4  # Number of layers in each dense block
growth_rate = 32  # Number of filters in each layer within a dense block
compression_factor = 0.5  # Compression factor for transition blocks

# Create the DenseNet model
model = DenseNet(input_shape, num_classes, num_blocks, num_layers, growth_rate, compression_factor)

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Fit the model
history = model.fit(train_data, train_labels, epochs=50, batch_size=32, validation_data=(test_data, test_labels))
# Out:
# Epoch 1/50
# 68/68 [==============================] - 230s 3s/step - loss: 1.8090 - accuracy: 0.5028 - val_loss: 14.0857 - val_accuracy: 0.0500
# Epoch 2/50
# 68/68 [==============================] - 262s 4s/step - loss: 0.7870 - accuracy: 0.8137 - val_loss: 7.1539 - val_accuracy: 0.0667
# Epoch 3/50
# 68/68 [==============================] - 230s 3s/step - loss: 0.4679 - accuracy: 0.8962 - val_loss: 1.4329 - val_accuracy: 0.5333
# Epoch 4/50
# 68/68 [==============================] - 351s 5s/step - loss: 0.3003 - accuracy: 0.9351 - val_loss: 2.8871 - val_accuracy: 0.2500
# Epoch 5/50
# 68/68 [==============================] - 367s 5s/step - loss: 0.2330 - accuracy: 0.9476 - val_loss: 2.0605 - val_accuracy: 0.4426
# Epoch 6/50
# 68/68 [==============================] - 339s 5s/step - loss: 0.1553 - accuracy: 0.9680 - val_loss: 0.8177 - val_accuracy: 0.7593
# Epoch 7/50
# 68/68 [==============================] - 322s 5s/step - loss: 0.1243 - accuracy: 0.9741 - val_loss: 0.7498 - val_accuracy: 0.7611
# Epoch 8/50
# 68/68 [==============================] - 323s 5s/step - loss: 0.1259 - accuracy: 0.9727 - val_loss: 11.3667 - val_accuracy: 0.1241
# Epoch 9/50
# 68/68 [==============================] - 323s 5s/step - loss: 0.0904 - accuracy: 0.9796 - val_loss: 5.5853 - val_accuracy: 0.2037
# Epoch 10/50
# 68/68 [==============================] - 321s 5s/step - loss: 0.1023 - accuracy: 0.9768 - val_loss: 0.2776 - val_accuracy: 0.9278
# Epoch 11/50
# 68/68 [==============================] - 322s 5s/step - loss: 0.0512 - accuracy: 0.9926 - val_loss: 0.6584 - val_accuracy: 0.7815
# Epoch 12/50
# 68/68 [==============================] - 323s 5s/step - loss: 0.0628 - accuracy: 0.9856 - val_loss: 3.1851 - val_accuracy: 0.2741
# Epoch 13/50
# 68/68 [==============================] - 321s 5s/step - loss: 0.0508 - accuracy: 0.9889 - val_loss: 1.4763 - val_accuracy: 0.6556
# Epoch 14/50
# 68/68 [==============================] - 321s 5s/step - loss: 0.0431 - accuracy: 0.9917 - val_loss: 0.8756 - val_accuracy: 0.7981
# Epoch 15/50
# 68/68 [==============================] - 320s 5s/step - loss: 0.0272 - accuracy: 0.9944 - val_loss: 0.1445 - val_accuracy: 0.9630
# Epoch 16/50
# 68/68 [==============================] - 320s 5s/step - loss: 0.0213 - accuracy: 0.9968 - val_loss: 2.5168 - val_accuracy: 0.5074
# Epoch 17/50
# 68/68 [==============================] - 321s 5s/step - loss: 0.0220 - accuracy: 0.9958 - val_loss: 1.1261 - val_accuracy: 0.7019
# Epoch 18/50
# 68/68 [==============================] - 321s 5s/step - loss: 0.0823 - accuracy: 0.9791 - val_loss: 9.2293 - val_accuracy: 0.1685
# Epoch 19/50
# 68/68 [==============================] - 319s 5s/step - loss: 0.0500 - accuracy: 0.9898 - val_loss: 5.3050 - val_accuracy: 0.2370
# Epoch 20/50
# 68/68 [==============================] - 318s 5s/step - loss: 0.0166 - accuracy: 0.9995 - val_loss: 0.2973 - val_accuracy: 0.9222
# Epoch 21/50
# 68/68 [==============================] - 320s 5s/step - loss: 0.0071 - accuracy: 0.9995 - val_loss: 0.0969 - val_accuracy: 0.9778
# Epoch 22/50
# 68/68 [==============================] - 321s 5s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 0.9685
# Epoch 23/50
# 68/68 [==============================] - 321s 5s/step - loss: 0.0052 - accuracy: 0.9991 - val_loss: 0.1124 - val_accuracy: 0.9685
# Epoch 24/50
# 68/68 [==============================] - 321s 5s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0980 - val_accuracy: 0.9833
# Epoch 25/50
# 68/68 [==============================] - 320s 5s/step - loss: 0.0053 - accuracy: 0.9995 - val_loss: 0.0946 - val_accuracy: 0.9704
# Epoch 26/50
# 68/68 [==============================] - 322s 5s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 0.9722
# Epoch 27/50
# 68/68 [==============================] - 321s 5s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1005 - val_accuracy: 0.9759
# Epoch 28/50
# 68/68 [==============================] - 321s 5s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9833
# Epoch 29/50
# 68/68 [==============================] - 320s 5s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9815
# Epoch 30/50
# 68/68 [==============================] - 321s 5s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9796
# Epoch 31/50
# 68/68 [==============================] - 321s 5s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0836 - val_accuracy: 0.9815
# Epoch 32/50
# 68/68 [==============================] - 320s 5s/step - loss: 0.0075 - accuracy: 0.9986 - val_loss: 16.0712 - val_accuracy: 0.0852
# Epoch 33/50
# 68/68 [==============================] - 322s 5s/step - loss: 0.0556 - accuracy: 0.9847 - val_loss: 12.9533 - val_accuracy: 0.1907
# Epoch 34/50
# 68/68 [==============================] - 320s 5s/step - loss: 0.0989 - accuracy: 0.9736 - val_loss: 5.8644 - val_accuracy: 0.4296
# Epoch 35/50
# 68/68 [==============================] - 293s 4s/step - loss: 0.0473 - accuracy: 0.9884 - val_loss: 1.1048 - val_accuracy: 0.7630
# Epoch 36/50
# 68/68 [==============================] - 167s 2s/step - loss: 0.0693 - accuracy: 0.9782 - val_loss: 1.1849 - val_accuracy: 0.7093
# Epoch 37/50
# 68/68 [==============================] - 168s 2s/step - loss: 0.0392 - accuracy: 0.9917 - val_loss: 3.7258 - val_accuracy: 0.2870
# Epoch 38/50
# 68/68 [==============================] - 168s 2s/step - loss: 0.0136 - accuracy: 0.9981 - val_loss: 0.1574 - val_accuracy: 0.9667
# Epoch 39/50
# 68/68 [==============================] - 167s 2s/step - loss: 0.0074 - accuracy: 0.9995 - val_loss: 0.0872 - val_accuracy: 0.9796
# Epoch 40/50
# 68/68 [==============================] - 167s 2s/step - loss: 0.0073 - accuracy: 0.9986 - val_loss: 0.4760 - val_accuracy: 0.8889
# Epoch 41/50
# 68/68 [==============================] - 167s 2s/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 1.1529 - val_accuracy: 0.6796
# Epoch 42/50
# 68/68 [==============================] - 167s 2s/step - loss: 0.0065 - accuracy: 0.9991 - val_loss: 0.1894 - val_accuracy: 0.9537
# Epoch 43/50
# 68/68 [==============================] - 167s 2s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.5297 - val_accuracy: 0.8630
# Epoch 44/50
# 68/68 [==============================] - 167s 2s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1042 - val_accuracy: 0.9722
# Epoch 45/50
# 68/68 [==============================] - 167s 2s/step - loss: 0.0042 - accuracy: 0.9995 - val_loss: 0.0817 - val_accuracy: 0.9796
# Epoch 46/50
# 68/68 [==============================] - 167s 2s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1039 - val_accuracy: 0.9759
# Epoch 47/50
# 68/68 [==============================] - 167s 2s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 0.9796
# Epoch 48/50
# 68/68 [==============================] - 168s 2s/step - loss: 0.0042 - accuracy: 0.9995 - val_loss: 0.2190 - val_accuracy: 0.9444
# Epoch 49/50
# 68/68 [==============================] - 167s 2s/step - loss: 0.0037 - accuracy: 0.9995 - val_loss: 0.7523 - val_accuracy: 0.8537
# Epoch 50/50
# 68/68 [==============================] - 167s 2s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0878 - val_accuracy: 0.9833

# %%
model.save("DenseNet_3.h5")

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
tf.keras.models.save_model(model,'DenseNet3.hdf5')

# %%
# Evaluate the model on the test data
predictions = model.predict(test_data)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(test_labels, axis=1)

test_loss, test_acc = model.evaluate(test_data, test_labels)
print('Test Loss:', test_loss)

accuracy = np.mean(predicted_labels == true_labels)
print('Accuracy:', accuracy*100)
# Out:
# 17/17 [==============================] - 8s 473ms/step
# 17/17 [==============================] - 8s 465ms/step - loss: 0.0878 - accuracy: 0.9833
# Test Loss: 0.08775635063648224
# Accuracy: 98.33333333333333

# %%
from sklearn.metrics import classification_report

# Make predictions on the test data
predictions = model.predict(test_data)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(test_labels, axis=1)

# Print the classification report
print(classification_report(true_labels, predicted_labels))
# Out:
# 17/17 [==============================] - 8s 487ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94        18
#            1       1.00      1.00      1.00        23
#            2       1.00      0.94      0.97        52
#            3       0.95      1.00      0.97        35
#            4       0.95      1.00      0.98        21
#            5       1.00      1.00      1.00        33
#            6       1.00      0.97      0.98        32
#            7       0.96      0.96      0.96        28
#            8       1.00      0.94      0.97        17
#            9       0.93      1.00      0.96        27
#           10       0.97      1.00      0.98        28
#           11       0.96      1.00      0.98        26
#           12       1.00      1.00      1.00        17
#           13       1.00      1.00      1.00        20
#           14       1.00      1.00      1.00        34
#           15       1.00      1.00      1.00        15
#           16       1.00      1.00      1.00        30
#           17       1.00      1.00      1.00        18
#           18       1.00      1.00      1.00        18
#           19       0.96      1.00      0.98        26
#           20       1.00      0.95      0.98        22
#
#     accuracy                           0.98       540
#    macro avg       0.99      0.98      0.98       540
# weighted avg       0.98      0.98      0.98       540

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['max_pooling2d[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 32)   18464       ['activation_1[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 96)   0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 96)  384         ['concatenate[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 56, 56, 96)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 32)   27680       ['activation_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 128)  0           ['concatenate[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 128)  512        ['concatenate_1[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 56, 56, 128)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 32)   36896       ['activation_3[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 56, 56, 160)  0           ['concatenate_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 160)  640        ['concatenate_2[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 56, 56, 160)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 32)   46112       ['activation_4[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 56, 56, 192)  0           ['concatenate_2[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 192)  768        ['concatenate_3[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 56, 56, 192)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 96)   18528       ['activation_5[0][0]']
#
#  average_pooling2d (AveragePool  (None, 28, 28, 96)  0           ['conv2d_5[0][0]']
#  ing2D)
#
#  batch_normalization_6 (BatchNo  (None, 28, 28, 96)  384         ['average_pooling2d[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 28, 28, 96)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 32)   27680       ['activation_6[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 28, 28, 128)  0           ['average_pooling2d[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 28, 28, 128)  512        ['concatenate_4[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 32)   36896       ['activation_7[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 28, 28, 160)  0           ['concatenate_4[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 28, 28, 160)  640        ['concatenate_5[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 28, 28, 160)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   46112       ['activation_8[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 28, 28, 192)  0           ['concatenate_5[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 28, 28, 192)  768        ['concatenate_6[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 28, 28, 192)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 32)   55328       ['activation_9[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 28, 28, 224)  0           ['concatenate_6[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 224)  896        ['concatenate_7[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 28, 28, 224)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 112)  25200       ['activation_10[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 14, 14, 112)  0          ['conv2d_10[0][0]']
#  oling2D)
#
#  batch_normalization_11 (BatchN  (None, 14, 14, 112)  448        ['average_pooling2d_1[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 14, 14, 112)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 14, 14, 32)   32288       ['activation_11[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 14, 14, 144)  0           ['average_pooling2d_1[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 14, 14, 144)  576        ['concatenate_8[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 14, 14, 144)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 14, 14, 32)   41504       ['activation_12[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 14, 14, 176)  0           ['concatenate_8[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 14, 14, 176)  704        ['concatenate_9[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 14, 14, 176)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 14, 14, 32)   50720       ['activation_13[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 14, 14, 208)  0           ['concatenate_9[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 14, 14, 208)  832        ['concatenate_10[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 14, 14, 208)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 14, 14, 32)   59936       ['activation_14[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 14, 14, 240)  0           ['concatenate_10[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 14, 14, 240)  960        ['concatenate_11[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 14, 14, 240)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 120)  28920       ['activation_15[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 7, 7, 120)   0           ['conv2d_15[0][0]']
#  oling2D)
#
#  batch_normalization_16 (BatchN  (None, 7, 7, 120)   480         ['average_pooling2d_2[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 7, 7, 120)    0           ['batch_normalization_16[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 7, 7, 32)     34592       ['activation_16[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 7, 7, 152)    0           ['average_pooling2d_2[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 7, 7, 152)   608         ['concatenate_12[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 7, 7, 152)    0           ['batch_normalization_17[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 7, 7, 32)     43808       ['activation_17[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 7, 7, 184)    0           ['concatenate_12[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 7, 7, 184)   736         ['concatenate_13[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 7, 7, 184)    0           ['batch_normalization_18[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 7, 7, 32)     53024       ['activation_18[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 7, 7, 216)    0           ['concatenate_13[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 7, 7, 216)   864         ['concatenate_14[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 7, 7, 216)    0           ['batch_normalization_19[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 7, 7, 32)     62240       ['activation_19[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 7, 7, 248)    0           ['concatenate_14[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 7, 7, 248)   992         ['concatenate_15[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 7, 7, 248)    0           ['batch_normalization_20[0][0]']
#
#  global_average_pooling2d (Glob  (None, 248)         0           ['activation_20[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 21)           5229        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 773,845
# Trainable params: 767,237
# Non-trainable params: 6,608
# __________________________________________________________________________________________________

# %%
# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
